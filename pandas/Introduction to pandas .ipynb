# %%
import pandas as pd

# %%
rackets = pd.Series(["X fire 2","yonex dg 2 slim ", "viper xt 5000"])
rackets
# Out:
# 0            X fire 2
# 1    yonex dg 2 slim
# 2       viper xt 5000
# dtype: object

# %%
owners_name = ["Asif", "Faisal", "Shagoto"]

owners = pd.Series(owners_name)
owners
# Out:
# 0       Asif
# 1     Faisal
# 2    Shagoto
# dtype: object

# %%
racket_owners_df = pd.DataFrame({"Racket model": rackets, "Owner's name" : owners})
racket_owners_df
# Out:
#        Racket model Owner's name
# 0          X fire 2         Asif
# 1  yonex dg 2 slim        Faisal
# 2     viper xt 5000      Shagoto

# %% [markdown]
# ### Another way

# %%
racket_owners_df2 = pd.DataFrame(rackets,columns= ["Racket Model"])
racket_owners_df2["Owner's name"] = owners
racket_owners_df2
# Out:
#        Racket Model Owner's name
# 0          X fire 2         Asif
# 1  yonex dg 2 slim        Faisal
# 2     viper xt 5000      Shagoto

# %%
car_data = pd.read_csv("car-sales.csv")
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data.to_csv("exported-car-data.csv",index=False)

# %%
exported_car_data = pd.read_csv("exported-car-data.csv")

exported_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
link_exported_data = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
link_exported_data.head()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# ...

# %% [markdown]
# ## Describe Data

# %%
# Arritbute

car_data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_data.empty
# Out:
# False

# %%
car_data.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
type(car_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
columns_name = car_data.columns
columns_name
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
 car_data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.info() , car_sales_missing.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes
# (None,
#  Make        1
#  Colour      1
#  Odometer    4
#  Doors       1
#  Price       2
#  dtype: int64)

# %%
car_data.median()
# Out:
# Odometer (KM)    57369.0
# Doors                4.0
# dtype: float64

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_data["Odometer (KM)"].sum()
# Out:
# 786014

# %%
len(car_data)
# Out:
# 10

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Viewing and selecting data

# %%
car_data.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_data.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_data["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# .loc % iloc 
favourite_player = pd.Series(["Lin Dan","Lee Chong Wee","Kevin","Tawfiq Hidayet"],
                            index = [5,1,36,98])

favourite_player
# Out:
# 5            Lin Dan
# 1      Lee Chong Wee
# 36             Kevin
# 98    Tawfiq Hidayet
# dtype: object

# %%
favourite_player.index
# Out:
# Int64Index([5, 1, 36, 98], dtype='int64')

# %%
favourite_player.argsort()
# Out:
# 5     2
# 1     1
# 36    0
# 98    3
# dtype: int64

# %%
favourite_player.loc[1]
# Out:
# 'Lee Chong Wee'

# %%
price_of_meat = pd.DataFrame([100,130,110],
                     index=["Beef","Mutton","Chiken"],
                     columns=["Price"])
price_of_meat
# Out:
#         Price
# Beef      100
# Mutton    130
# Chiken    110

# %%
price_of_meat.index
# Out:
# Index(['Beef', 'Mutton', 'Chiken'], dtype='object')

# %%
price_of_meat.iloc[2]
# Out:
# Price    110
# Name: Chiken, dtype: int64

# %%
price_of_meat.iloc[:1]
# Out:
#       Price
# Beef    100

# %%
price_of_meat.iloc["Chiken"] # this will result an error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-feb8f1e9a417> in <module>
# ----> 1 price_of_meat.iloc["Chiken"] # this will result an error
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
# ...

# %%
price_of_meat.loc["Chiken"]
# Out:
# Price    110
# Name: Chiken, dtype: int64

# %%
price_of_meat.loc[1] # this will result an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-e5fb76705e44> in <module>
# ...

# %%
price_of_meat.loc[:"Mutton"]
# Out:
#         Price
# Beef      100
# Mutton    130

# %%
price_of_meat["Mutton":]
# Out:
#         Price
# Mutton    130
# Chiken    110

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_data.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
favourite_player
# Out:
# 5            Lin Dan
# 1      Lee Chong Wee
# 36             Kevin
# 98    Tawfiq Hidayet
# dtype: object

# %%
favourite_player.iloc[2]
# Out:
# 'Kevin'

# %%
favourite_player.iloc[:3]
# Out:
# 5           Lin Dan
# 1     Lee Chong Wee
# 36            Kevin
# dtype: object

# %%
car_data.loc[:2]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_data.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_data.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_data.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_data.Odometer (KM)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-48ef74c127a9> in <module>
# ----> 1 car_data.Odometer (KM)
#
# E:\codes\Machine_learning\mlcourse_codes\pandas\env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
 car_data[car_data["Make"] != "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 1   Honda    Red          87899      4   $5,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
 car_data[car_data["Make"] == "Toyota"]["Odometer (KM)"].mean()
# Out:
# 85451.25

# %%
car_data["Make"] != "Toyota"
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: Make, dtype: bool

# %%
car_data[car_data["Odometer (KM)"]> 100000 ]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
#crosstab

pd.crosstab(car_data["Price"],car_data["Odometer (KM)"])
# Out:
# Odometer (KM)  11179   31600   32549   45698   54738   60000   87899   99213   \
# Price
# $22,000.00          1       0       0       0       0       0       0       0
# $3,500.00           0       0       0       0       0       0       0       0
# $4,000.00           0       0       0       0       0       0       0       0
# $4,500.00           0       0       0       0       0       0       0       1
# $5,000.00           0       0       0       0       0       0       1       0
# $6,250.00           0       0       0       0       0       1       0       0
# $7,000.00           0       0       1       0       1       0       0       0
# $7,500.00           0       0       0       1       0       0       0       0
# $9,700.00           0       1       0       0       0       0       0       0
#
# Odometer (KM)  150043  213095
# Price
# $22,000.00          0       0
# $3,500.00           0       1
# $4,000.00           1       0
# $4,500.00           0       0
# ...

# %%
pd.crosstab(car_data["Make"] , car_data["Price"])
# Out:
# Price   $22,000.00  $3,500.00  $4,000.00  $4,500.00  $5,000.00  $6,250.00  \
# Make
# BMW              1          0          0          0          0          0
# Honda            0          0          0          0          1          0
# Nissan           0          1          0          0          0          0
# Toyota           0          0          1          1          0          1
#
# Price   $7,000.00  $7,500.00  $9,700.00
# Make
# BMW             0          0          0
# Honda           1          1          0
# Nissan          0          0          1
# Toyota          1          0          0

# %%
car_data["Make"].unique() , car_data["Price"].unique()
# Out:
# (array(['Toyota', 'Honda', 'BMW', 'Nissan'], dtype=object),
#  array(['$4,000.00', '$5,000.00', '$7,000.00', '$22,000.00', '$3,500.00',
#         '$4,500.00', '$7,500.00', '$6,250.00', '$9,700.00'], dtype=object))

# %%
car_data[car_data["Price"] == "$7,000.00"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 7   Honda   Blue          54738      4  $7,000.00

# %%
car_data.groupby(["Price"]).median()
# Out:
#             Odometer (KM)  Doors
# Price
# $22,000.00        11179.0    5.0
# $3,500.00        213095.0    4.0
# $4,000.00        150043.0    4.0
# $4,500.00         99213.0    4.0
# $5,000.00         87899.0    4.0
# $6,250.00         60000.0    4.0
# $7,000.00         43643.5    3.5
# $7,500.00         45698.0    4.0
# $9,700.00         31600.0    4.0

# %%
car_data["Price"].value_counts()
# Out:
# $7,000.00     2
# $5,000.00     1
# $4,500.00     1
# $3,500.00     1
# $6,250.00     1
# $9,700.00     1
# $22,000.00    1
# $4,000.00     1
# $7,500.00     1
# Name: Price, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_data["Odometer (KM)"].hist(bins=15);

# %%
car_data.Price
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_data

# %%
car_data["Price"].hist(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#car_data["Price"] = car_data["Price"].str.replace("[/$/,]","").astype(float)
# Out:
# <ipython-input-53-dc4fc1846023>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_data["Price"] = car_data["Price"].str.replace("[/$/,]","").astype(float)

# %%
car_data["Price"]= car_data["Price"].str.replace("[/$/,/.']","").str[:-2].astype(int)
# Out:
# <ipython-input-84-5dbede847f01>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_data["Price"]= car_data["Price"].str.replace("[/$/,/.']","").str[:-2].astype(int)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_data["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  Manipulating Data

# %% [markdown]
# if we want to perform any string operation on the string (object ) column , we can do that by accessing the string value of the attribure by .str

# %%
lower_maker_name = car_data["Make"].str.lower()
type(lower_maker_name), lower_maker_name
# Out:
# (pandas.core.series.Series,
#  0    toyota
#  1     honda
#  2    toyota
#  3       bmw
#  4    nissan
#  5    toyota
#  6     honda
#  7     honda
#  8    toyota
#  9    nissan
#  Name: Make, dtype: object)

# %%
car_data["Make"]

# %%
car_data["Make"] = car_data["Make"].str.lower()
car_data["Make"]

# %% [markdown]
# # Working with missing Data

# %%
car_data_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_data_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_data_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_data_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %%
car_data_missing.isna().sum()
# Out:
# Make        1
# Colour      1
# Odometer    4
# Doors       1
# Price       2
# dtype: int64

# %%
car_data_missing["Odometer"]
# Out:
# 0    150043.0
# 1     87899.0
# 2         NaN
# 3     11179.0
# 4    213095.0
# 5         NaN
# 6         NaN
# 7         NaN
# 8     60000.0
# 9     31600.0
# Name: Odometer, dtype: float64

# %%
car_data_missing["Odometer"].fillna(car_data_missing["Odometer"].mean(),inplace=True)

car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_data_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_data_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_data_missing_dropped  =  car_data_missing.dropna()

# %%
car_data_missing_dropped
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_data_missing_dropped.to_csv("car-data-missing-dropped.csv",index= False)

# %%
pd.read_csv("car-data-missing-dropped.csv")
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# # Adding columns with Series

# %%
number_of_row = len(car_data)
number_of_colums = len(car_data.columns)

print(f"Number of row : {number_of_row} \t Number of colum : {number_of_colums}")
# Out:
# Number of row : 10 	 Number of colum : 5

# %%
seats_column = pd.Series([5,3,2,5,10])

# %%
seats_column
# Out:
# 0     5
# 1     3
# 2     2
# 3     5
# 4    10
# dtype: int64

# %%
car_data["Seats"] = seats_column

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    3.0
# 2  Toyota   Blue          32549      3   7000    2.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500   10.0
# 5  Toyota  Green          99213      4   4500    NaN
# 6   Honda   Blue          45698      4   7500    NaN
# 7   Honda   Blue          54738      4   7000    NaN
# 8  Toyota  White          60000      4   6250    NaN
# 9  Nissan  White          31600      4   9700    NaN

# %%
car_data.fillna(5,inplace=True)

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats
# 0  Toyota  White         150043      4   4000    5.0
# 1   Honda    Red          87899      4   5000    3.0
# 2  Toyota   Blue          32549      3   7000    2.0
# 3     BMW  Black          11179      5  22000    5.0
# 4  Nissan  White         213095      4   3500   10.0
# 5  Toyota  Green          99213      4   4500    5.0
# 6   Honda   Blue          45698      4   7500    5.0
# 7   Honda   Blue          54738      4   7000    5.0
# 8  Toyota  White          60000      4   6250    5.0
# 9  Nissan  White          31600      4   9700    5.0

# %% [markdown]
# # Adding columns with list

# %%
fuel_econnomy = [7.5,5.0,6.3,8.2,6.35]


car_data["Fuel per 100KM"] = fuel_econnomy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-5c7f25cb1e7e> in <module>
#       2
#       3
# ----> 4 car_data["Fuel per 100KM"] = fuel_econnomy
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# E:\codes\Machine_learning\mlcourse_codes\numpy\env\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ...

# %%
fuel_econnomy = [7.5,5.0,6.3,8.2,6.35,3.6,4.9,7.9,10,9.3]


car_data["Fuel per 100KM"] = fuel_econnomy
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30

# %%
car_data

# %%
car_data["Fuels used (L)"]= car_data["Odometer (KM)"]/100 * car_data["Fuel per 100KM"]
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)
# 0      11253.2250
# 1       4394.9500
# 2       2050.5870
# 3        916.6780
# 4      13531.5325
# 5       3571.6680
# 6       2239.2020
# 7       4324.3020
# 8       6000.0000
# ...

# %%
# create a column with single value  

car_data["Number of wheel"] = 4
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety  Number of wheel
# 0      11253.2250                True                4
# 1       4394.9500                True                4
# ...

# %%
car_data["Passed road safety"] = True
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety  Number of wheel
# 0      11253.2250                True                4
# 1       4394.9500                True                4
# ...

# %%
car_data.drop("Number of wheel", axis=1,inplace=True)

# %%
car_data.drop("Number of wheel",axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
car_data[car_data["Make"] =='BMW']
# Out:
#   Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 3  BMW  Black          11179      5  22000    5.0             8.2
#
#    Fuels used (L)  Passed road safety
# 3         916.678                True

# %% [markdown]
# # Shuffling the data

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
shuffled_car_data   = car_data.sample(frac= 1)
shuffled_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 9  Nissan  White          31600      4   9700    5.0            9.30
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 3     BMW  Black          11179      5  22000    5.0            8.20
#
#    Fuels used (L)  Passed road safety
# 5       3571.6680                True
# 9       2938.8000                True
# 8       6000.0000                True
# 4      13531.5325                True
# ...

# %%
car_data

# %%
reset_shuffled_car_data=shuffled_car_data.reset_index(drop = True )

# %%
shuffled_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 9  Nissan  White          31600      4   9700    5.0            9.30
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 3     BMW  Black          11179      5  22000    5.0            8.20
#
#    Fuels used (L)  Passed road safety
# 5       3571.6680                True
# 9       2938.8000                True
# 8       6000.0000                True
# 4      13531.5325                True
# ...

# %%
reset_shuffled_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  Green          99213      4   4500    5.0            3.60
# 1  Nissan  White          31600      4   9700    5.0            9.30
# 2  Toyota  White          60000      4   6250    5.0           10.00
# 3  Nissan  White         213095      4   3500   10.0            6.35
# 4  Toyota  White         150043      4   4000    5.0            7.50
# 5   Honda   Blue          45698      4   7500    5.0            4.90
# 6  Toyota   Blue          32549      3   7000    2.0            6.30
# 7   Honda    Red          87899      4   5000    3.0            5.00
# 8   Honda   Blue          54738      4   7000    5.0            7.90
# 9     BMW  Black          11179      5  22000    5.0            8.20
#
#    Fuels used (L)  Passed road safety
# 0       3571.6680                True
# 1       2938.8000                True
# 2       6000.0000                True
# 3      13531.5325                True
# ...

# %%
car_data_shuffled = car_data.sample(frac = 1)

# %%
car_data_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 4   Honda   Blue          45698      4   7500.0            4.90
# 5  Toyota   Blue          32549      3   7000.0            6.30
# 6   Honda    Red          87899      4   5000.0            5.00
# 9  Toyota  White         150043      4   4000.0            7.50
# 2  Nissan  White         213095      4   3500.0            6.35
# 3     BMW  Black          11179      5  22000.0            8.20
# 7  Nissan  White          31600      4   9700.0            9.30
# 0   Honda   Blue          54738      4   7000.0            7.90
# 1  Toyota  White          60000      4   6250.0           10.00
# 8  Toyota  Green          99213      4   4500.0            3.60
#
#    Number of wheel
# 4                4
# 5                4
# 6                4
# 9                4
# 2                4
# 3                4
# 7                4
# 0                4
# 1                4
# 8                4

# %%
car_data_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 0      4   Honda   Blue          45698      4   7500.0            4.90
# 1      5  Toyota   Blue          32549      3   7000.0            6.30
# 2      6   Honda    Red          87899      4   5000.0            5.00
# 3      9  Toyota  White         150043      4   4000.0            7.50
# 4      2  Nissan  White         213095      4   3500.0            6.35
# 5      3     BMW  Black          11179      5  22000.0            8.20
# 6      7  Nissan  White          31600      4   9700.0            9.30
# 7      0   Honda   Blue          54738      4   7000.0            7.90
# 8      1  Toyota  White          60000      4   6250.0           10.00
# 9      8  Toyota  Green          99213      4   4500.0            3.60
#
#    Number of wheel
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# ...

# %%
car_data_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Fuel per 100KM  \
# 4   Honda   Blue          45698      4   7500.0            4.90
# 5  Toyota   Blue          32549      3   7000.0            6.30
# 6   Honda    Red          87899      4   5000.0            5.00
# 9  Toyota  White         150043      4   4000.0            7.50
# 2  Nissan  White         213095      4   3500.0            6.35
# 3     BMW  Black          11179      5  22000.0            8.20
# 7  Nissan  White          31600      4   9700.0            9.30
# 0   Honda   Blue          54738      4   7000.0            7.90
# 1  Toyota  White          60000      4   6250.0           10.00
# 8  Toyota  Green          99213      4   4500.0            3.60
#
#    Number of wheel
# 4                4
# 5                4
# 6                4
# 9                4
# 2                4
# 3                4
# 7                4
# 0                4
# 1                4
# 8                4

# %%
car_data_shuffled["Odometer (KM)"] = car_data_shuffled["Odometer (KM)"].apply(lambda x:x/1.6)

# %%
car_data_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 9  Nissan  White      19750.000      4   9700    5.0            9.30
# 7   Honda   Blue      34211.250      4   7000    5.0            7.90
# 1   Honda    Red      54936.875      4   5000    3.0            5.00
# 6   Honda   Blue      28561.250      4   7500    5.0            4.90
# 4  Nissan  White     133184.375      4   3500   10.0            6.35
# 5  Toyota  Green      62008.125      4   4500    5.0            3.60
# 0  Toyota  White      93776.875      4   4000    5.0            7.50
# 2  Toyota   Blue      20343.125      3   7000    2.0            6.30
# 8  Toyota  White      37500.000      4   6250    5.0           10.00
# 3     BMW  Black       6986.875      5  22000    5.0            8.20
#
#    Fuels used (L)  Passed road safety
# 9       2938.8000                True
# 7       4324.3020                True
# 1       4394.9500                True
# 6       2239.2020                True
# ...

# %%
car_data.rename(columns={"Odometer (KM)":"Odometer (Miles)"},inplace=True)

# %%
car_data.rename(columns={"Odometer (KM)": "Odometer (Miles)"})
# Out:
#      Make Colour  Odometer (Miles)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White            150043      4   4000    5.0            7.50
# 1   Honda    Red             87899      4   5000    3.0            5.00
# 2  Toyota   Blue             32549      3   7000    2.0            6.30
# 3     BMW  Black             11179      5  22000    5.0            8.20
# 4  Nissan  White            213095      4   3500   10.0            6.35
# 5  Toyota  Green             99213      4   4500    5.0            3.60
# 6   Honda   Blue             45698      4   7500    5.0            4.90
# 7   Honda   Blue             54738      4   7000    5.0            7.90
# 8  Toyota  White             60000      4   6250    5.0           10.00
# 9  Nissan  White             31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# ...

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Seats  Fuel per 100KM  \
# 0  Toyota  White         150043      4   4000    5.0            7.50
# 1   Honda    Red          87899      4   5000    3.0            5.00
# 2  Toyota   Blue          32549      3   7000    2.0            6.30
# 3     BMW  Black          11179      5  22000    5.0            8.20
# 4  Nissan  White         213095      4   3500   10.0            6.35
# 5  Toyota  Green          99213      4   4500    5.0            3.60
# 6   Honda   Blue          45698      4   7500    5.0            4.90
# 7   Honda   Blue          54738      4   7000    5.0            7.90
# 8  Toyota  White          60000      4   6250    5.0           10.00
# 9  Nissan  White          31600      4   9700    5.0            9.30
#
#    Fuels used (L)  Passed road safety
# 0      11253.2250                True
# 1       4394.9500                True
# 2       2050.5870                True
# 3        916.6780                True
# ...

# %%
car_data=car_data[["Make","Price","Seats","Colour",'Fuels used (L)','Fuel per 100KM','Doors','Odometer (KM)','Passed road safety']]
# Out:
#      Make  Price  Seats Colour  Fuels used (L)  Fuel per 100KM  Doors  \
# 0  Toyota   4000    5.0  White      11253.2250            7.50      4
# 1   Honda   5000    3.0    Red       4394.9500            5.00      4
# 2  Toyota   7000    2.0   Blue       2050.5870            6.30      3
# 3     BMW  22000    5.0  Black        916.6780            8.20      5
# 4  Nissan   3500   10.0  White      13531.5325            6.35      4
# 5  Toyota   4500    5.0  Green       3571.6680            3.60      4
# 6   Honda   7500    5.0   Blue       2239.2020            4.90      4
# 7   Honda   7000    5.0   Blue       4324.3020            7.90      4
# 8  Toyota   6250    5.0  White       6000.0000           10.00      4
# 9  Nissan   9700    5.0  White       2938.8000            9.30      4
#
#    Odometer (KM)  Passed road safety
# 0         150043                True
# 1          87899                True
# 2          32549                True
# 3          11179                True
# ...

# %%
df = car_data[["Make","Price","Seats","Colour"]]
df
# Out:
#      Make  Price  Seats Colour
# 0  Toyota   4000    5.0  White
# 1   Honda   5000    3.0    Red
# 2  Toyota   7000    2.0   Blue
# 3     BMW  22000    5.0  Black
# 4  Nissan   3500   10.0  White
# 5  Toyota   4500    5.0  Green
# 6   Honda   7500    5.0   Blue
# 7   Honda   7000    5.0   Blue
# 8  Toyota   6250    5.0  White
# 9  Nissan   9700    5.0  White

# %%
car_data.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price', 'Seats',
#        'Fuel per 100KM', 'Fuels used (L)', 'Passed road safety'],
#       dtype='object')
